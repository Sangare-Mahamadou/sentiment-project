# %%
import pandas as pd


orange = pd.read_csv('comments_orangeMoney_cleaned.csv')
wave = pd.read_csv('comments_cleaned_wave.csv')

# %%
orange['Service'] = 'Orange Money'
wave['Service'] = 'WAVE'

# %%
orange.head()
# Out:
#    Unnamed: 0                                           comments       Service
# 0           0                      C'est pas petit réseau orange  Orange Money
# 1           1                                                Oui  Orange Money
# 2           2                                    Plus pertinents  Orange Money
# 3           3  Aka laissez les gens tranquille. Vous manquez ...  Orange Money
# 4           4                              Il y'a pas CMR sur ça  Orange Money

# %%
df_final = pd.concat([orange, wave], ignore_index=True)
df_final.to_csv('comments_combined_cleaned_sentiment.csv', index=False)
